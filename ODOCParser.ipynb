# %% [markdown]
# # **ODOC Scraper**

# %% [markdown]
# ### Library Install

# %%
import requests
import os
from datetime import datetime
from datetime import date
from zipfile import *
from zipfile import ZipFile 
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd
import re
import pickle
import bz2
import _pickle as cPickle

# %% [markdown]
# ### Functions

# %%
# Pickle a file and then compress it into a file with extension 
def compressed_pickle(title, data):
 with bz2.BZ2File(title + '.pbz2', 'w') as f: 
     cPickle.dump(data, f)

    
# Load any compressed pickle file
def decompress_pickle(file):
 data = bz2.BZ2File(file, 'rb')
 data = cPickle.load(data)
 return data

# %% [markdown]
# ### Download data and place in a zip folder

# %%
# zip url
url = 'http://publicdata.doc.state.ok.us/vendor%20extract.zip'

# download the file contents in binary format
r = requests.get(url)

# dd/mm/YY H:M:S
location = "../Paul/ODOC_Raw"
extension = ".zip"
file_name =  location + extension
file_name

# write to zip folder
with open(file_name, "wb") as zip:
    zip.write(r.content)

# %% [markdown]
# ### Unzip the folder

# %%
with ZipFile('ODOC_Raw.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('ODOC_Raw')
   print('File is unzipped in ODOC_Raw folder')
# Out:
# File is unzipped in ODOC_Raw folder

# %% [markdown]
# ### Alias Data

# %%
# open the alias file and remove whitespace characters like `\n` at the end of each line 
with open("ODOC_Raw/Vendor_Alias_Extract_Text.dat") as f:
    content = f.readlines()
content = [x.strip() for x in content] 

# convert to npy array
alias_arr = np.array(content)

# convert to df
alias_df = pd.DataFrame(alias_arr)

# rename the 1st column
alias_df.rename(columns={ alias_df.columns[0]: "Raw" }, inplace = True)

# PARSE OUT COLUMNS
alias_df['DOC_NUM'] = alias_df['Raw'].str.slice(stop=10)
alias_df['Raw'] = alias_df['Raw'].str.slice(start=10)
alias_df['LAST_NAME'] = alias_df['Raw'].str.slice(stop=30)
alias_df['Raw'] = alias_df['Raw'].str.slice(start=30)
alias_df['FIRST_NAME'] = alias_df['Raw'].str.slice(stop=30)
alias_df['Raw'] = alias_df['Raw'].str.slice(start=30)
alias_df['MIDDLE_NAME'] = alias_df['Raw'].str.slice(stop=30)
alias_df['Raw'] = alias_df['Raw'].str.slice(start=30)
alias_df['SUFFIX'] = alias_df['Raw'].str.slice(stop=5)
alias_df['Raw'] = alias_df['Raw'].str.slice(start=5)

# drop the last row since it is designated to DO NOT USE
alias_df = alias_df[alias_df.MIDDLE_NAME != 'DO NOT USE']

# drop the original 'raw' column
del alias_df['Raw']
alias_df

# write to compressed pickle
compressed_pickle('alias_compressed.pickle', alias_df.to_pickle('alias.pickle'))

alias_df
# Out:
#            DOC_NUM                       LAST_NAME  \
# 0       0000008359  MESLES
# 1       0000010337  SAWYER
# 2       0000012556  GOFORTH
# 3       0000020413  KNIGHTON
# 4       0000022574  HOGNER
# ...            ...                             ...
# 598879  0000993890  GUINN
# 598880  0000996281  PILON
# 598881  0000997494  AKERS
# 598882  0000997494  AKERS
# 598883  0000997494  PARKINSON
#
#                             FIRST_NAME MIDDLE_NAME SUFFIX
# 0                               ARDELL
# 1       FRANK                                    N
# 2       PAMELA                                   B
# 3       RAYMOND                                  J
# 4                             CLARENCE
# ...                                ...         ...    ...
# 598879                        JEANETTE
# 598880  GARY                                     V
# 598881                            CONV
# 598882  MARK                                     W
# 598883                            JOHN
#
# [598883 rows x 5 columns]

# %% [markdown]
# ### Offense Data

# %%
# open the alias file and remove whitespace characters like `\n` at the end of each line 
with open("ODOC_Raw/Vendor_Offense_Extract_Text.dat") as f:
    content = f.readlines()
content = [x.strip() for x in content] 

# convert to npy array
off_arr = np.array(content)

# convert to df
off_df = pd.DataFrame(off_arr)

# rename the 1st column
off_df.rename(columns={ off_df.columns[0]: "Raw" }, inplace = True)

# PARASE OUT COLUMNS
off_df['STATUTE_CODE'] = off_df['Raw'].str.slice(stop=38)
off_df['Raw'] = off_df['Raw'].str.slice(start=38)
off_df['DESCRIPTION'] = off_df['Raw'].str.slice(stop=40)
off_df['Raw'] = off_df['Raw'].str.slice(start=40)
off_df['VIOLENT'] = off_df['Raw'].str.slice(stop=1)
off_df['Raw'] = off_df['Raw'].str.slice(start=1)

# drop the original 'raw' column
del off_df['Raw']
off_df

# write to compressed pickle
compressed_pickle('offense_compressed.pickle', off_df.to_pickle('offense.pickle'))

off_df
# Out:
#                                 STATUTE_CODE  \
# 0     0-0
# 1     10-1144
# 2     10-1627
# 3     10-26
# 4     10-404.1
# ...                                      ...
# 1171  74-924
# 1172  76-23
# 1173  82-1020.22
# 1174  82-105.2
# 1175  82-1455
#
#                                    DESCRIPTION VIOLENT
# 0     UNKNOWN - FOR WARRANTS ONLY                    N
# 1     ACTS CAUSING JUVENILE DELINQUENCY              N
# 2     DEPRIVATION OF LAWFUL CUSTODY                  N
# 3     UNLAWFUL ASSUMPTION OF CUSTODY OF CHILD        N
# 4     SEX OFFENDER PROVIDING SERVICES TO CHILD       N
# ...                                        ...     ...
# 1171  FILE FALSE STATEMENT PUBLIC EMPLOYEE RET       N
# 1172  TAMPERING WITH UTILITIES                       N
# 1173  VIOLATION OF WATER RESOURCES RULES/REGS        N
# 1174  UNAUTHORIZED USE OF WATER                      N
# 1175  LITTERING A SCENIC RIVER AREA                  N
#
# [1176 rows x 3 columns]

# %% [markdown]
# ### Profile Data

# %%
# open the alias file and remove whitespace characters like `\n` at the end of each line 
with open("ODOC_Raw/Vendor_Profile_Extract_Text.dat") as f:
    content = f.readlines()
content = [x.strip() for x in content] 

# convert to npy array
prof_arr = np.array(content)

# convert to df
prof_df = pd.DataFrame(prof_arr)

# rename the 1st column
prof_df.rename(columns={ prof_df.columns[0]: "Raw" }, inplace = True)

# PARSE OUT COLUMNS
prof_df['DOC_NUM'] = prof_df['Raw'].str.slice(stop=10)
prof_df['Raw'] = prof_df['Raw'].str.slice(start=10)
prof_df['LAST_NAME'] = prof_df['Raw'].str.slice(stop=30)
prof_df['Raw'] = prof_df['Raw'].str.slice(start=30)
prof_df['FIRST_NAME'] = prof_df['Raw'].str.slice(stop=30)
prof_df['Raw'] = prof_df['Raw'].str.slice(start=30)
prof_df['MIDDLE_NAME'] = prof_df['Raw'].str.slice(stop=30)
prof_df['Raw'] = prof_df['Raw'].str.slice(start=30)
prof_df['SUFFIX'] = prof_df['Raw'].str.slice(stop=5)
prof_df['Raw'] = prof_df['Raw'].str.slice(start=5)
prof_df['LAST_MOVE_DATE'] = prof_df['Raw'].str.slice(stop=9)
prof_df['Raw'] = prof_df['Raw'].str.slice(start=9)
prof_df['FACILITY'] = prof_df['Raw'].str.slice(stop=40)
prof_df['Raw'] = prof_df['Raw'].str.slice(start=40)
prof_df['BIRTH_DATE'] = prof_df['Raw'].str.slice(stop=9)
prof_df['Raw'] = prof_df['Raw'].str.slice(start=9)
prof_df['SEX'] = prof_df['Raw'].str.slice(stop=1)
prof_df['Raw'] = prof_df['Raw'].str.slice(start=1)
prof_df['RACE'] = prof_df['Raw'].str.slice(stop=40)
prof_df['Raw'] = prof_df['Raw'].str.slice(start=40)
prof_df['HAIR'] = prof_df['Raw'].str.slice(stop=40)
prof_df['Raw'] = prof_df['Raw'].str.slice(start=40)
prof_df['HEIGHT_FT'] = prof_df['Raw'].str.slice(stop=2)
prof_df['Raw'] = prof_df['Raw'].str.slice(start=2)
prof_df['HEIGHT_IN'] = prof_df['Raw'].str.slice(stop=2)
prof_df['Raw'] = prof_df['Raw'].str.slice(start=2)
prof_df['WEIGHT'] = prof_df['Raw'].str.slice(stop=4)
prof_df['Raw'] = prof_df['Raw'].str.slice(start=4)
prof_df['EYE'] = prof_df['Raw'].str.slice(stop=40)
prof_df['Raw'] = prof_df['Raw'].str.slice(start=40)
prof_df['STATUS'] = prof_df['Raw'].str.slice(stop=10)
prof_df['Raw'] = prof_df['Raw'].str.slice(start=10)

# drop the original 'raw' column
del prof_df['Raw']
prof_df

# write to compressed pickle
compressed_pickle('profile_compressed.pickle', prof_df.to_pickle('profile.pickle'))

prof_df
# Out:
#            DOC_NUM                       LAST_NAME  \
# 0       0000008359  MESLES
# 1       0000010337  SAWYER
# 2       0000012556  GOFORTH
# 3       0000020413  KNIGHTON
# 4       0000022574  STOCKTON
# ...            ...                             ...
# 320979  0000990510  SKAGGS
# 320980  0000993597  FOSTER
# 320981  0000993890  GUINN
# 320982  0000996281  PILON
# 320983  0000997494  AKERS
#
#                             FIRST_NAME                     MIDDLE_NAME SUFFIX  \
# 0       ARDELL
# 1       FRANK                           N
# 2       PAMELA                          B
# 3       RAYMOND                         J
# 4       MELVIN                          H
# ...                                ...                             ...    ...
# 320979  BOBBY                           L
# 320980  LAFONDA                         F
# 320981  JEANETTE
# 320982  GARY                            V
# 320983  MARK                            W
#
#        LAST_MOVE_DATE                                  FACILITY BIRTH_DATE  \
# 0           03-MAR-86  INACTIVE                                  06-APR-87
# 1           12-JUN-91  INACTIVE                                  01-JAN-00
# 2           13-NOV-89  INACTIVE                                  06-FEB-51
# 3           18-APR-80  INACTIVE                                  20-AUG-48
# 4           02-JAN-97  INACTIVE                                  07-DEC-45
# ...               ...                                       ...        ...
# 320979      01-AUG-94  INACTIVE                                  26-JAN-33
# 320980      07-AUG-01  INACTIVE                                  30-AUG-63
# 320981      15-SEP-94  INACTIVE                                  09-APR-39
# 320982      19-OCT-94  INACTIVE                                  18-SEP-53
# 320983      30-NOV-97  INACTIVE                                  17-JUL-70
#
#        SEX                                      RACE  \
# 0        M
# 1        M  WHITE
# 2        M  NATIVE AMERICAN
# 3        M  BLACK
# 4        M  WHITE
# ...     ..                                       ...
# 320979   M  WHITE
# 320980   F  WHITE
# 320981   F  WHITE
# 320982   M  WHITE
# 320983   M  WHITE
#
#                                             HAIR HEIGHT_FT HEIGHT_IN WEIGHT  \
# 0
# 1       UNK                                             5         1
# 2       BROWN                                           5         9    116
# 3       BROWN
# 4       BROWN                                           5         10   150
# ...                                          ...       ...       ...    ...
# 320979  BROWN                                           5         10   145
# 320980  RED                                             5         7    170
# 320981  BROWN                                           5         4    118
# 320982  BROWN                                           6         2    185
# 320983  BROWN                                           5         9    178
#
#                                              EYE    STATUS
# 0                                                 Inactive
# 1       BLACK                                     Inactive
# 2       N/R                                       Inactive
# 3       BROWN                                     Inactive
# 4       GRAY                                      Inactive
# ...                                          ...       ...
# 320979  HAZEL                                     Inactive
# 320980  BLUE                                      Inactive
# 320981  BROWN                                     Inactive
# 320982  GREEN                                     Inactive
# 320983  BLUE                                      Inactive
#
# [320984 rows x 16 columns]

# %% [markdown]
# ### Sentence Data

# %%
# open the alias file and remove whitespace characters like `\n` at the end of each line 
with open("ODOC_Raw/Vendor_sentence_Extract_Text.dat") as f:
    content = f.readlines()
content = [x.strip() for x in content] 

# convert to npy array
sent_arr = np.array(content)

# convert to df
sent_df = pd.DataFrame(sent_arr)

# rename the 1st column
sent_df.rename(columns={ sent_df.columns[0]: "Raw" }, inplace = True)

# PARSE OUT COLUMNS
sent_df['DOC_NUM'] = sent_df['Raw'].str.slice(stop=10)
sent_df['Raw'] = sent_df['Raw'].str.slice(start=10)
sent_df['STATUTE_CODE'] = sent_df['Raw'].str.slice(stop=40)
sent_df['Raw'] = sent_df['Raw'].str.slice(start=40)
sent_df['SENTENCING_COUNTY'] = sent_df['Raw'].str.slice(stop=40)
sent_df['Raw'] = sent_df['Raw'].str.slice(start=40)
sent_df['JS_DATE'] = sent_df['Raw'].str.slice(stop=8)
sent_df['Raw'] = sent_df['Raw'].str.slice(start=8)
sent_df['CRF_NUMBER'] = sent_df['Raw'].str.slice(stop=40)
sent_df['Raw'] = sent_df['Raw'].str.slice(start=40)
sent_df['INCARCERATED_TERM_IN_YEARS'] = sent_df['Raw'].str.slice(stop=10)
sent_df['Raw'] = sent_df['Raw'].str.slice(start=10)
sent_df['PROBATION_TERM_IN_YEARS'] = sent_df['Raw'].str.slice(stop=10)
sent_df['Raw'] = sent_df['Raw'].str.slice(start=10)

# remove white space in numeric columns
sent_df['INCARCERATED_TERM_IN_YEARS'] = sent_df['INCARCERATED_TERM_IN_YEARS'].str.strip()
sent_df['PROBATION_TERM_IN_YEARS'] = sent_df['PROBATION_TERM_IN_YEARS'].str.strip()

# SET COLUMN TYPES
#sent_df["DOC_NUM"] = pd.to_numeric(sent_df["DOC_NUM"])
sent_df['INCARCERATED_TERM_IN_YEARS'] = pd.to_numeric(sent_df['INCARCERATED_TERM_IN_YEARS'])
#sent_df['PROBATION_TERM_IN_YEARS'] = pd.to_numeric(sent_df['PROBATION_TERM_IN_YEARS'])

# drop the original 'raw' column
del sent_df['Raw']
sent_df

# filter to Tulsa County Only
sent_df = sent_df[sent_df["SENTENCING_COUNTY"].str.contains("TULSA COUNTY COURT")]

# Write to compressed pickle
compressed_pickle('sentence_compressed.pickle', sent_df.to_pickle('sentence.pickle'))

sent_df
# Out:
#             DOC_NUM                              STATUTE_CODE  \
# 3        0000020413  21-1731
# 4        0000022574  21-741
# 5        0000022574  47-11-902
# 6        0000022663  21-801.A
# 7        0000022663  21-801.A
# ...             ...                                       ...
# 1359998  0000864451  21-1283
# 1359999  0000864461  21-1550.41
# 1360000  0000864461  21-1550.41
# 1360088  0000864667  21-1720
# 1360144  0000864973  47-4-103
#
#                                 SENTENCING_COUNTY   JS_DATE  \
# 3        TULSA COUNTY COURT                        19-APR-7
# 4        TULSA COUNTY COURT                        03-MAR-6
# 5        TULSA COUNTY COURT                        24-OCT-9
# 6        TULSA COUNTY COURT                        22-APR-6
# 7        TULSA COUNTY COURT                        22-APR-6
# ...                                           ...       ...
# 1359998  TULSA COUNTY COURT                        05-OCT-2
# 1359999  TULSA COUNTY COURT                        31-JUL-2
# 1360000  TULSA COUNTY COURT                        31-JUL-2
# 1360088  TULSA COUNTY COURT                        07-DEC-2
# 1360144  TULSA COUNTY COURT                        14-DEC-2
#
#                                        CRF_NUMBER  INCARCERATED_TERM_IN_YEARS  \
# 3        777-240                                                          NaN
# 4        420-393                                                        777.0
# 5        494-4167                                                         NaN
# 6        4 2-513                                                          3.0
# 7        4 2-513                                                          1.0
# ...                                           ...                         ...
# 1359998  0CF-2020-88                                                      NaN
# 1359999  02020-1486                                                       0.0
# 1360000  02020-1486                                                       NaN
# 1360088                                  020-2701                         NaN
# 1360144  020-4768                                                         NaN
#
#         PROBATION_TERM_IN_YEARS
# 3                         00000
# 4                          7.00
# 5                         00000
# 6                          6.00
# 7                          2.00
# ...                         ...
# 1359998                   00000
# 1359999                    1.00
# 1360000                   00000
# 1360088
# 1360144                   00000
#
# [211091 rows x 7 columns]

# %% [markdown]
# ### Combine all the dataframes into one master df - Inner Joins on DOC_NUM & STATUTE_CODE

# %%
# set to view all columns for QC
pd.set_option('display.max_columns', None)

# Start with Sentence and Profile on DocNum using innjer join
sent_prof_MERGE = pd.merge(left=sent_df, right=prof_df, left_on='DOC_NUM', right_on='DOC_NUM')

# Bring in Offense based on DocNum using inner join
sent_prof_MERGE['STATUTE_CODE'] = sent_prof_MERGE['STATUTE_CODE'].str.strip()
off_df['STATUTE_CODE'] = off_df['STATUTE_CODE'].str.strip()
off_prof_sent_MERGE = pd.merge(left=sent_prof_MERGE, right=off_df, left_on='STATUTE_CODE', right_on='STATUTE_CODE')

# drop duplicate rows
odoc_final = off_prof_sent_MERGE
# odoc_final = odoc_merge.drop_duplicates(keep = 'first')

# View final dataframe before edits
odoc_final
# Out:
#            DOC_NUM STATUTE_CODE                         SENTENCING_COUNTY  \
# 0       0000020413      21-1731  TULSA COUNTY COURT
# 1       0000071854      21-1731  TULSA COUNTY COURT
# 2       0000074305      21-1731  TULSA COUNTY COURT
# 3       0000076538      21-1731  TULSA COUNTY COURT
# 4       0000076709      21-1731  TULSA COUNTY COURT
# ...            ...          ...                                       ...
# 209618  0000854693     47-2-129  TULSA COUNTY COURT
# 209619  0000854693     47-2-129  TULSA COUNTY COURT
# 209620  0000857822      69-1211  TULSA COUNTY COURT
# 209621  0000858022      2-6-125  TULSA COUNTY COURT
# 209622  0000862068    47-12-201  TULSA COUNTY COURT
#
#          JS_DATE                                CRF_NUMBER  \
# 0       19-APR-7  777-240
# 1       18-NOV-9  191-4524
# 2       19-NOV-9  393-3374
# 3       17-MAR-8  080-438
# 4       23-AUG-9  393-3429
# ...          ...                                       ...
# 209618  14-JAN-2  0CF-19-4659
# 209619  20-JUL-2  0CF-19-4659
# 209620  05-JUN-2  0CF-2020-1845
# 209621  15-JUN-2  0CF-2019-1661
# 209622  02-OCT-2  02020-3451
#
#         INCARCERATED_TERM_IN_YEARS PROBATION_TERM_IN_YEARS  \
# 0                              NaN                   00000
# 1                              0.0                    3.00
# 2                              0.0                    2.00
# 3                              0.0                    2.00
# 4                              0.0                    2.00
# ...                            ...                     ...
# 209618                         NaN                   00000
# 209619                         NaN                   00000
# 209620                         NaN                   00000
# 209621                         NaN                   00000
# 209622                         NaN                   00000
#
#                              LAST_NAME                      FIRST_NAME  \
# 0       KNIGHTON                        RAYMOND
# 1       WASHINGTON                      DONALD
# 2       GATEWOOD                        HERMAN
# 3       BLAYLOCK                        ROBERT
# 4       MACK                            HERMAN
# ...                                ...                             ...
# 209618  JOHNSON                         JOSHUA
# 209619  JOHNSON                         JOSHUA
# 209620  RUVALCABA                       GILBERTO
# 209621  DIOSDADO                        DAVID
# 209622  HARVEY                          JERMAINE
#
#                            MIDDLE_NAME SUFFIX LAST_MOVE_DATE  \
# 0       J                                          18-APR-80
# 1       R                               SR         13-APR-93
# 2                                                  01-SEP-94
# 3       C                                          16-MAR-82
# 4       E                                          06-NOV-08
# ...                                ...    ...            ...
# 209618  DEAN
# 209619  DEAN
# 209620  MANUEL
# 209621
# 209622  SHAQUAN
#
#                                         FACILITY BIRTH_DATE SEX  \
# 0       INACTIVE                                  20-AUG-48   M
# 1       INACTIVE                                  12-JAN-46   M
# 2       INACTIVE                                  12-MAR-43   M
# 3       INACTIVE                                  23-JUL-38   M
# 4       INACTIVE                                  23-JUN-45   M
# ...                                          ...        ...  ..
# 209618  NORTHEAST DISTRICT OFFICE                 14-JUN-91   M
# 209619  NORTHEAST DISTRICT OFFICE                 14-JUN-91   M
# 209620  TULSA COUNTY DISTRICT                     04-FEB-90   M
# 209621  TULSA COUNTY DISTRICT                     10-JAN-92   M
# 209622  CENTRAL DISTRICT - SHERIDAN OFFICE        13-DEC-00   M
#
#                                             RACE  \
# 0       BLACK
# 1       BLACK
# 2       BLACK
# 3       WHITE
# 4       BLACK
# ...                                          ...
# 209618  WHITE
# 209619  WHITE
# 209620  HISPANIC
# 209621  HISPANIC
# 209622  BLACK
#
#                                             HAIR HEIGHT_FT HEIGHT_IN WEIGHT  \
# 0       BROWN
# 1       BLACK                                           6         3    220
# 2       BLACK                                           5         7    165
# 3       BLONDE                                          6         1    220
# 4       GRAY, ETC.                                      5         6    240
# ...                                          ...       ...       ...    ...
# 209618  BLONDE                                          6         3    200
# 209619  BLONDE                                          6         3    200
# 209620
# 209621
# 209622  BLACK                                           5         11   169
#
#                                              EYE    STATUS  \
# 0       BROWN                                     Inactive
# 1       BROWN                                     Inactive
# 2       BROWN                                     Inactive
# 3       N/R                                       Inactive
# 4       BROWN                                     Inactive
# ...                                          ...       ...
# 209618  BLUE                                        Active
# 209619  BLUE                                        Active
# 209620                                              Active
# 209621                                              Active
# 209622  BROWN                                       Active
#
#                                      DESCRIPTION VIOLENT
# 0       LARCENY OF MERCH FROM RETAILER                 N
# 1       LARCENY OF MERCH FROM RETAILER                 N
# 2       LARCENY OF MERCH FROM RETAILER                 N
# 3       LARCENY OF MERCH FROM RETAILER                 N
# 4       LARCENY OF MERCH FROM RETAILER                 N
# ...                                          ...     ...
# 209618  DISSEMINATING CONFIDENTIAL INFORMATION         N
# 209619  DISSEMINATING CONFIDENTIAL INFORMATION         N
# 209620  CONSTRUCTION OF STATE/FED RIGHT-OF-WAY         N
# 209621  MOVING QUARANTINED LIVESTOCK                   N
# 209622  FAILURE TO DISPLAY HEADLIGHTS                  N
#
# [209623 rows x 24 columns]

# %% [markdown]
# ### Compress the Pickles for Git Storage Requirements

# %% [markdown]
# ### Decompress Pickles

# %%
# decompress files
sentence = decompress_pickle('sentence_compressed.pickle.pbz2')
alias = decompress_pickle('alias_compressed.pickle.pbz2')
offense = decompress_pickle('offense_compressed.pickle.pbz2')
profile = decompress_pickle('profile_compressed.pickle.pbz2')

# %%
# View one for sanity check
sentence = pd.read_pickle('sentence.pickle')
sentence
# Out:
#          DOC_NUM                              STATUTE_CODE  \
# 0           8359  21-1720
# 1          10337  21-701.7
# 2          10337  21-701.7
# 3          20413  21-1731
# 4          22574  21-741
# ...          ...                                       ...
# 1360620   996281  21-798
# 1360621   996281  21-444
# 1360622   997494  21-799
# 1360623   997494  21-799
# 1360624   997494  21-799
#
#                                 SENTENCING_COUNTY   JS_DATE  \
# 0        POTTAWATOMIE COUNTY COURT                 13-MAR-1
# 1        BRYAN COUNTY COURT                        13-APR-2
# 2        BRYAN COUNTY COURT                        14-DEC-6
# 3        TULSA COUNTY COURT                        19-APR-7
# 4        TULSA COUNTY COURT                        03-MAR-6
# ...                                           ...       ...
# 1360620  UNKNOWN COUNTY COURT                      08-JUN-8
# 1360621  WASHINGTON JURISDICTION                   29-MAY-8
# 1360622  CALIFORNIA JURISDICTION                   01-FEB-9
# 1360623  CALIFORNIA JURISDICTION                   01-FEB-9
# 1360624  CALIFORNIA JURISDICTION                   01-FEB-9
#
#                                        CRF_NUMBER  INCARCERATED_TERM_IN_YEARS  \
# 0        32010-300                                                        NaN
# 1        0 1-0                                                          777.0
# 2        220-15645                                                        NaN
# 3        777-240                                                          NaN
# 4        420-393                                                        777.0
# ...                                           ...                         ...
# 1360620  2 9-897                                                        777.0
# 1360621  079-1236                                                         1.0
# 1360622  494-8235                                                         0.0
# 1360623  494-8235                                                         0.0
# 1360624  494-8235                                                         0.0
#
#         PROBATION_TERM_IN_YEARS
# 0                         00000
# 1                          7.00
# 2                         00000
# 3                         00000
# 4                          7.00
# ...                         ...
# 1360620                    7.00
# 1360621                    0.00
# 1360622                    5.00
# 1360623                    3.00
# 1360624                    3.00
#
# [1360625 rows x 7 columns]
